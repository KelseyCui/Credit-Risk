# %% [markdown]
# # 1. Data summary

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_credit = pd.read_csv("/Users/kelseycui/Desktop/Updated_German_Credit_Data_with_700_Good_and_300_Bad_Risk.csv", index_col= 0)
print(df_credit.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
#  9   Risk              1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 85.9+ KB
# None

# %%
#Looking unique values
print(df_credit.nunique())
#Looking the data of the first 5 rows
print(df_credit.head())
# Out:
# Age                  53
# Sex                   2
# Job                   4
# Housing               3
# Saving accounts       4
# Checking account      3
# Credit amount       921
# Duration             33
# Purpose               8
# Risk                  2
# dtype: int64
#             Age     Sex  Job Housing Saving accounts Checking account  \
# Unnamed: 0
# 0            67    male    2     own             NaN           little
# 1            22  female    2     own          little         moderate
# 2            49    male    1     own          little              NaN
# 3            45    male    2    free          little           little
# 4            53    male    2    free          little           little
#
#             Credit amount  Duration              Purpose  Risk
# Unnamed: 0
# 0                    1169         6             radio/TV   bad
# 1                    5951        48             radio/TV  good
# 2                    2096        12            education   bad
# 3                    7882        42  furniture/equipment  good
# 4                    4870        24                  car  good

# %% [markdown]
# # 2. Exploration of relationship between variables and credit risk

# %% [markdown]
# ## Target variable distribution

# %%
# it's a library that we work with plotly
import plotly.offline as py 
py.init_notebook_mode(connected=True) # this code, allow us to work with offline plotly version
import plotly.graph_objs as go # it's like "plt" of matplot
import plotly.tools as tls # It's useful to we get some tools of plotly
import warnings # This library will be used to ignore some warnings
from collections import Counter # To do counter of some features

trace0 = go.Bar(x = df_credit[df_credit["Risk"]== 'good']["Risk"].value_counts().index.values,
                y = df_credit[df_credit["Risk"]== 'good']["Risk"].value_counts().values,
                name='Good credit')

trace1 = go.Bar(
            x = df_credit[df_credit["Risk"]== 'bad']["Risk"].value_counts().index.values,
            y = df_credit[df_credit["Risk"]== 'bad']["Risk"].value_counts().values,
            name='Bad credit')

data = [trace0, trace1]

layout = go.Layout()

layout = go.Layout(yaxis=dict(title='Count'),xaxis=dict(title='Risk Variable'),title='Target variable distribution')

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='grouped-bar')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.graph_objs as go
import plotly.subplots as sp

# Data extraction
df_good = df_credit.loc[df_credit["Risk"] == 'good']['Age'].values.tolist()
df_bad = df_credit.loc[df_credit["Risk"] == 'bad']['Age'].values.tolist()
df_age = df_credit['Age'].values.tolist()

# First plot
trace0 = go.Histogram(
    x=df_good,
    histnorm='probability',
    name="Good Credit"
)

# Second plot
trace1 = go.Histogram(
    x=df_bad,
    histnorm='probability',
    name="Bad Credit"
)

# Third plot
trace2 = go.Histogram(
    x=df_age,
    histnorm='probability',
    name="Overall Age"
)

# Creating the grid using plotly.subplots.make_subplots
fig = sp.make_subplots(rows=2, cols=2, specs=[[{}, {}], [{'colspan': 2}, None]],
                       subplot_titles=('Good', 'Bad', 'General Distribution'))

# Setting the figs
fig.add_trace(trace0, 1, 1)
fig.add_trace(trace1, 1, 2)
fig.add_trace(trace2, 2, 1)

# Updating layout
fig.update_layout(showlegend=True, title='Age Distribution', bargap=0.05)

# Displaying the plot
fig.show()

# %% [markdown]
# ## Create a new variable to categorize the age with different credit risk

# %%
#Let's look the Credit Amount column
interval = (18, 25, 35, 60, 120)

cats = ['Student', 'Young', 'Adult', 'Senior']
df_credit["Age_cat"] = pd.cut(df_credit.Age, interval, labels=cats)


df_good = df_credit[df_credit["Risk"] == 'good']
df_bad = df_credit[df_credit["Risk"] == 'bad']

# %%
trace0 = go.Box(
    y=df_good["Credit amount"],
    x=df_good["Age_cat"],
    name='Good credit',
    marker=dict(
        color='#3D9970'
    )
)

trace1 = go.Box(
    y=df_bad['Credit amount'],
    x=df_bad['Age_cat'],
    name='Bad credit',
    marker=dict(
        color='#FF4136'
    )
)
    
data = [trace0, trace1]

layout = go.Layout(
    yaxis=dict(
        title='Credit Amount (US Dollar)',
        zeroline=False
    ),
    xaxis=dict(
        title='Age Categorical'
    ),
    boxmode='group'
)
fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='box-age-cat')

# %% [markdown]
# ## Distribution of credit risk across different groups based on their housing status

# %%
#First plot
trace0 = go.Bar(
    x = df_credit[df_credit["Risk"]== 'good']["Housing"].value_counts().index.values,
    y = df_credit[df_credit["Risk"]== 'good']["Housing"].value_counts().values,
    name='Good credit'
)

#Second plot
trace1 = go.Bar(
    x = df_credit[df_credit["Risk"]== 'bad']["Housing"].value_counts().index.values,
    y = df_credit[df_credit["Risk"]== 'bad']["Housing"].value_counts().values,
    name="Bad Credit"
)

data = [trace0, trace1]

layout = go.Layout(
    title='Housing Distribuition'
)


fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='Housing-Grouped')

# %% [markdown]
# ## Distribution of credit risk based on housing status

# %%
fig = {
    "data": [
        {
            "type": 'violin',
            "x": df_good['Housing'],
            "y": df_good['Credit amount'],
            "legendgroup": 'Good Credit',
            "scalegroup": 'No',
            "name": 'Good Credit',
            "side": 'negative',
            "box": {
                "visible": True
            },
            "meanline": {
                "visible": True
            },
            "line": {
                "color": 'blue'
            }
        },
        {
            "type": 'violin',
            "x": df_bad['Housing'],
            "y": df_bad['Credit amount'],
            "legendgroup": 'Bad Credit',
            "scalegroup": 'No',
            "name": 'Bad Credit',
            "side": 'positive',
            "box": {
                "visible": True
            },
            "meanline": {
                "visible": True
            },
            "line": {
                "color": 'green'
            }
        }
    ],
    "layout" : {
        "yaxis": {
            "zeroline": False,
        },
        "violingap": 0,
        "violinmode": "overlay"
    }
}


py.iplot(fig, filename = 'violin/split', validate = False)

# %% [markdown]
# ## Investigate the relationship between gender and credit risk

# %%
import plotly.graph_objects as go
import plotly.subplots as sp

# First plot
trace0 = go.Bar(
    x=df_credit[df_credit["Risk"] == 'good']["Sex"].value_counts().index.values,
    y=df_credit[df_credit["Risk"] == 'good']["Sex"].value_counts().values,
    name='Good credit'
)

# First plot 2
trace1 = go.Bar(
    x=df_credit[df_credit["Risk"] == 'bad']["Sex"].value_counts().index.values,
    y=df_credit[df_credit["Risk"] == 'bad']["Sex"].value_counts().values,
    name="Bad Credit"
)

# Second plot
trace2 = go.Box(
    x=df_credit[df_credit["Risk"] == 'good']["Sex"],
    y=df_credit[df_credit["Risk"] == 'good']["Credit amount"],
    name=trace0.name
)

# Second plot 2
trace3 = go.Box(
    x=df_credit[df_credit["Risk"] == 'bad']["Sex"],
    y=df_credit[df_credit["Risk"] == 'bad']["Credit amount"],
    name=trace1.name
)

# Creating subplots
fig = sp.make_subplots(rows=1, cols=2, 
                       subplot_titles=('Sex Count', 'Credit Amount by Sex'))

# Adding traces
fig.add_trace(trace0, row=1, col=1)
fig.add_trace(trace1, row=1, col=1)
fig.add_trace(trace2, row=1, col=2)
fig.add_trace(trace3, row=1, col=2)

# Updating layout
fig.update_layout(height=400, width=800, title='Sex Distribution', boxmode='group')

# Display the plot
fig.show()

# %% [markdown]
# ## Investigate the relationship between Job and credit risk

# %%
#First plot
trace0 = go.Bar(
    x = df_credit[df_credit["Risk"]== 'good']["Job"].value_counts().index.values,
    y = df_credit[df_credit["Risk"]== 'good']["Job"].value_counts().values,
    name='Good credit Distribuition'
)

#Second plot
trace1 = go.Bar(
    x = df_credit[df_credit["Risk"]== 'bad']["Job"].value_counts().index.values,
    y = df_credit[df_credit["Risk"]== 'bad']["Job"].value_counts().values,
    name="Bad Credit Distribuition"
)

data = [trace0, trace1]

layout = go.Layout(
    title='Job Distribuition'
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='grouped-bar')

# %% [markdown]
# ## Credit amount distribution by job

# %%
trace0 = go.Box(
    x=df_good["Job"],
    y=df_good["Credit amount"],
    name='Good credit'
)

trace1 = go.Box(
    x=df_bad['Job'],
    y=df_bad['Credit amount'],
    name='Bad credit'
)
    
data = [trace0, trace1]

layout = go.Layout(
    yaxis=dict(
        title='Credit Amount distribuition by Job'
    ),
    boxmode='group'
)
fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='box-age-cat')

# %%
fig = {
    "data": [
        {
            "type": 'violin',
            "x": df_good['Job'],
            "y": df_good['Age'],
            "legendgroup": 'Good Credit',
            "scalegroup": 'No',
            "name": 'Good Credit',
            "side": 'negative',
            "box": {
                "visible": True
            },
            "meanline": {
                "visible": True
            },
            "line": {
                "color": 'blue'
            }
        },
        {
            "type": 'violin',
            "x": df_bad['Job'],
            "y": df_bad['Age'],
            "legendgroup": 'Bad Credit',
            "scalegroup": 'No',
            "name": 'Bad Credit',
            "side": 'positive',
            "box": {
                "visible": True
            },
            "meanline": {
                "visible": True
            },
            "line": {
                "color": 'green'
            }
        }
    ],
    "layout" : {
        "yaxis": {
            "zeroline": False,
        },
        "violingap": 0,
        "violinmode": "overlay"
    }
}


py.iplot(fig, filename = 'Age-Housing', validate = False)

# %% [markdown]
# ## Distribution of overall credit amount

# %%
import plotly.figure_factory as ff
import numpy as np

# Add histogram data
x1 = np.log(df_good['Credit amount']) 
x2 = np.log(df_bad["Credit amount"])

# Group data together
hist_data = [x1, x2]
group_labels = ['Good Credit', 'Bad Credit']

# Create distplot with custom bin_size
fig = ff.create_distplot(hist_data, group_labels, bin_size=.2)

# Plot!
py.iplot(fig, filename='Distplot with Multiple Datasets')

# %% [markdown]
# ## Distribution of saving accounts by risk

# %%
print("Description of Distribuition Saving accounts by Risk:  ")
print(pd.crosstab(df_credit["Saving accounts"],df_credit.Risk))

fig, ax = plt.subplots(3,1, figsize=(12,12))
g = sns.countplot(x="Saving accounts", data=df_credit, palette="hls", 
              ax=ax[0],hue="Risk")
g.set_title("Saving Accounts Count", fontsize=15)
g.set_xlabel("Saving Accounts type", fontsize=12)
g.set_ylabel("Count", fontsize=12)

g1 = sns.violinplot(x="Saving accounts", y="Job", data=df_credit, palette="hls", 
               hue = "Risk", ax=ax[1],split=True)
g1.set_title("Saving Accounts by Job", fontsize=15)
g1.set_xlabel("Savings Accounts type", fontsize=12)
g1.set_ylabel("Job", fontsize=12)

g = sns.boxplot(x="Saving accounts", y="Credit amount", data=df_credit, ax=ax[2],
            hue = "Risk",palette="hls")
g2.set_title("Saving Accounts by Credit Amount", fontsize=15)
g2.set_xlabel("Savings Accounts type", fontsize=12)
g2.set_ylabel("Credit Amount(US)", fontsize=12)

plt.subplots_adjust(hspace = 0.4,top = 0.9)

plt.show()
# Out:
# Description of Distribuition Saving accounts by Risk:
# Risk             bad  good
# Saving accounts
# little           179   424
# moderate          30    73
# quite rich        20    43
# rich              17    31

# %% [markdown]
# ## Distribution of purpose by risk

# %%
print("Values describe: ")
print(pd.crosstab(df_credit.Purpose, df_credit.Risk))

plt.figure(figsize = (14,12))

plt.subplot(221)
g = sns.countplot(x="Purpose", data=df_credit, 
              palette="hls", hue = "Risk")
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_xlabel("", fontsize=12)
g.set_ylabel("Count", fontsize=12)
g.set_title("Purposes Count", fontsize=20)

plt.subplot(222)
g1 = sns.violinplot(x="Purpose", y="Age", data=df_credit, 
                    palette="hls", hue = "Risk",split=True)
g1.set_xticklabels(g1.get_xticklabels(),rotation=45)
g1.set_xlabel("", fontsize=12)
g1.set_ylabel("Count", fontsize=12)
g1.set_title("Purposes by Age", fontsize=20)

plt.subplot(212)
g2 = sns.boxplot(x="Purpose", y="Credit amount", data=df_credit, 
               palette="hls", hue = "Risk")
g2.set_xlabel("Purposes", fontsize=12)
g2.set_ylabel("Credit Amount", fontsize=12)
g2.set_title("Credit Amount distribuition by Purposes", fontsize=20)

plt.subplots_adjust(hspace = 0.6, top = 0.8)

plt.show()
# Out:
# Values describe:
# Risk                 bad  good
# Purpose
# business              26    71
# car                  108   229
# domestic appliances    4     8
# education             21    38
# furniture/equipment   50   131
# radio/TV              86   194
# repairs                3    19
# vacation/others        2    10

# %% [markdown]
# ## Distribution between duration of the loans and credit risk & distribution between borrowing frequency and credit risk

# %%
plt.figure(figsize = (12,14))

g= plt.subplot(311)
g = sns.countplot(x="Duration", data=df_credit, 
              palette="hls",  hue = "Risk")
g.set_xlabel("Duration Distribuition", fontsize=12)
g.set_ylabel("Count", fontsize=12)
g.set_title("Duration Count", fontsize=20)

g1 = plt.subplot(312)
g1 = sns.pointplot(x="Duration", y ="Credit amount",data=df_credit,
                   hue="Risk", palette="hls")
g1.set_xlabel("Duration", fontsize=12)
g1.set_ylabel("Credit Amount(US)", fontsize=12)
g1.set_title("Credit Amount distribuition by Duration", fontsize=20)

g2 = plt.subplot(313)
g2 = sns.distplot(df_good["Duration"], color='g')
g2 = sns.distplot(df_bad["Duration"], color='r')
g2.set_xlabel("Duration", fontsize=12)
g2.set_ylabel("Frequency", fontsize=12)
g2.set_title("Duration Frequency x good and bad Credit", fontsize=20)

plt.subplots_adjust(wspace = 0.4, hspace = 0.4,top = 0.9)

plt.show()
# Out:
# /var/folders/v1/_6krp2m94h901xb6988gyr4r0000gn/T/ipykernel_16605/3076791316.py:18: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /var/folders/v1/_6krp2m94h901xb6988gyr4r0000gn/T/ipykernel_16605/3076791316.py:19: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# ## Distribution of checking account

# %%
#First plot
trace0 = go.Bar(
    x = df_credit[df_credit["Risk"]== 'good']["Checking account"].value_counts().index.values,
    y = df_credit[df_credit["Risk"]== 'good']["Checking account"].value_counts().values,
    name='Good credit Distribuition' 
    
)

#Second plot
trace1 = go.Bar(
    x = df_credit[df_credit["Risk"]== 'bad']["Checking account"].value_counts().index.values,
    y = df_credit[df_credit["Risk"]== 'bad']["Checking account"].value_counts().values,
    name="Bad Credit Distribuition"
)

data = [trace0, trace1]

layout = go.Layout(
    title='Checking accounts Distribuition',
    xaxis=dict(title='Checking accounts name'),
    yaxis=dict(title='Count'),
    barmode='group'
)


fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename = 'Age-ba', validate = False)

# %%
df_good = df_credit[df_credit["Risk"] == 'good']
df_bad = df_credit[df_credit["Risk"] == 'bad']

trace0 = go.Box(
    y=df_good["Credit amount"],
    x=df_good["Checking account"],
    name='Good credit',
    marker=dict(
        color='#3D9970'
    )
)

trace1 = go.Box(
    y=df_bad['Credit amount'],
    x=df_bad['Checking account'],
    name='Bad credit',
    marker=dict(
        color='#FF4136'
    )
)
    
data = [trace0, trace1]

layout = go.Layout(
    yaxis=dict(
        title='Cheking distribuition'
    ),
    boxmode='group'
)
fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='box-age-cat')

# %% [markdown]
# ## Relationship between Checking account and credit risk

# %%
print("Total values of the most missing variable: ")
print(df_credit.groupby("Checking account")["Checking account"].count())

plt.figure(figsize = (12,10))

g = plt.subplot(221)
g = sns.countplot(x="Checking account", data=df_credit, 
              palette="hls", hue="Risk")
g.set_xlabel("Checking Account", fontsize=12)
g.set_ylabel("Count", fontsize=12)
g.set_title("Checking Account Counting by Risk", fontsize=20)

g1 = plt.subplot(222)
g1 = sns.violinplot(x="Checking account", y="Age", data=df_credit, palette="hls", hue = "Risk",split=True)
g1.set_xlabel("Checking Account", fontsize=12)
g1.set_ylabel("Age", fontsize=12)
g1.set_title("Age by Checking Account", fontsize=20)

g2 = plt.subplot(212)
g2 = sns.boxplot(x="Checking account",y="Credit amount", data=df_credit,hue='Risk',palette="hls")
g2.set_xlabel("Checking Account", fontsize=12)
g2.set_ylabel("Credit Amount(US)", fontsize=12)
g2.set_title("Credit Amount by Cheking Account", fontsize=20)

plt.subplots_adjust(wspace = 0.2, hspace = 0.3, top = 0.9)

plt.show()
plt.show()
# Out:
# Total values of the most missing variable:
# Checking account
# little      245
# moderate    224
# rich         53
# Name: Checking account, dtype: int64

# %% [markdown]
# ## Distribution of Housing status * Job and credit risk

# %%
print(pd.crosstab(df_credit.Sex, df_credit.Job))
# Out:
# Job     0   1    2   3
# Sex
# female  7  41   98  22
# male    7  75  215  57

# %%
plt.figure(figsize = (10,6))

g = sns.violinplot(x="Housing",y="Job",data=df_credit,
                   hue="Risk", palette="hls",split=True)
g.set_xlabel("Housing", fontsize=12)
g.set_ylabel("Job", fontsize=12)
g.set_title("Housing x Job - Dist", fontsize=20)

plt.show()

# %%
print(pd.crosstab(df_credit["Checking account"],df_credit.Sex))
# Out:
# Sex               female  male
# Checking account
# little                76   169
# moderate              73   151
# rich                  19    34

# %%
date_int = ["Purpose", 'Sex']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_credit[date_int[0]], df_credit[date_int[1]]).style.background_gradient(cmap = cm)
# Out:
# <style type="text/css">
# #T_4c3df_row0_col0, #T_4c3df_row3_col0 {
#   background-color: #b5d9b5;
#   color: #000000;
# }
# #T_4c3df_row0_col1 {
#   background-color: #a4d0a4;
#   color: #000000;
# }
# #T_4c3df_row1_col0, #T_4c3df_row1_col1, #T_4c3df_row5_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_4c3df_row2_col0, #T_4c3df_row2_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_4c3df_row3_col1 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_4c3df_row4_col0 {
#   background-color: #0a850a;
#   color: #f1f1f1;
# }
# #T_4c3df_row4_col1 {
#   background-color: #7abc7a;
#   color: #000000;
# }
# #T_4c3df_row5_col1 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_4c3df_row6_col0, #T_4c3df_row7_col0 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_4c3df_row6_col1 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_4c3df_row7_col1 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# </style>
# <table id="T_4c3df">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_4c3df_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_4c3df_level0_col1" class="col_heading level0 col1" >male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Purpose</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c3df_level0_row0" class="row_heading level0 row0" >business</th>
#       <td id="T_4c3df_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_4c3df_row0_col1" class="data row0 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_4c3df_level0_row1" class="row_heading level0 row1" >car</th>
#       <td id="T_4c3df_row1_col0" class="data row1 col0" >46</td>
#       <td id="T_4c3df_row1_col1" class="data row1 col1" >127</td>
#     </tr>
#     <tr>
#       <th id="T_4c3df_level0_row2" class="row_heading level0 row2" >domestic appliances</th>
#       <td id="T_4c3df_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_4c3df_row2_col1" class="data row2 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_4c3df_level0_row3" class="row_heading level0 row3" >education</th>
#       <td id="T_4c3df_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_4c3df_row3_col1" class="data row3 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_4c3df_level0_row4" class="row_heading level0 row4" >furniture/equipment</th>
#       <td id="T_4c3df_row4_col0" class="data row4 col0" >44</td>
#       <td id="T_4c3df_row4_col1" class="data row4 col1" >63</td>
#     </tr>
#     <tr>
#       <th id="T_4c3df_level0_row5" class="row_heading level0 row5" >radio/TV</th>
#       <td id="T_4c3df_row5_col0" class="data row5 col0" >46</td>
#       <td id="T_4c3df_row5_col1" class="data row5 col1" >86</td>
#     </tr>
#     <tr>
#       <th id="T_4c3df_level0_row6" class="row_heading level0 row6" >repairs</th>
#       <td id="T_4c3df_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_4c3df_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_4c3df_level0_row7" class="row_heading level0 row7" >vacation/others</th>
#       <td id="T_4c3df_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_4c3df_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
date_int = ["Purpose", 'Sex']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_credit[date_int[0]], df_credit[date_int[1]]).style.background_gradient(cmap = cm)
# Out:
# <style type="text/css">
# #T_6adfd_row0_col0, #T_6adfd_row3_col0 {
#   background-color: #b5d9b5;
#   color: #000000;
# }
# #T_6adfd_row0_col1 {
#   background-color: #a4d0a4;
#   color: #000000;
# }
# #T_6adfd_row1_col0, #T_6adfd_row1_col1, #T_6adfd_row5_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_6adfd_row2_col0, #T_6adfd_row2_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_6adfd_row3_col1 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_6adfd_row4_col0 {
#   background-color: #0a850a;
#   color: #f1f1f1;
# }
# #T_6adfd_row4_col1 {
#   background-color: #7abc7a;
#   color: #000000;
# }
# #T_6adfd_row5_col1 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_6adfd_row6_col0, #T_6adfd_row7_col0 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_6adfd_row6_col1 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_6adfd_row7_col1 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# </style>
# <table id="T_6adfd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_6adfd_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_6adfd_level0_col1" class="col_heading level0 col1" >male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Purpose</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6adfd_level0_row0" class="row_heading level0 row0" >business</th>
#       <td id="T_6adfd_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_6adfd_row0_col1" class="data row0 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_6adfd_level0_row1" class="row_heading level0 row1" >car</th>
#       <td id="T_6adfd_row1_col0" class="data row1 col0" >46</td>
#       <td id="T_6adfd_row1_col1" class="data row1 col1" >127</td>
#     </tr>
#     <tr>
#       <th id="T_6adfd_level0_row2" class="row_heading level0 row2" >domestic appliances</th>
#       <td id="T_6adfd_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_6adfd_row2_col1" class="data row2 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6adfd_level0_row3" class="row_heading level0 row3" >education</th>
#       <td id="T_6adfd_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_6adfd_row3_col1" class="data row3 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_6adfd_level0_row4" class="row_heading level0 row4" >furniture/equipment</th>
#       <td id="T_6adfd_row4_col0" class="data row4 col0" >44</td>
#       <td id="T_6adfd_row4_col1" class="data row4 col1" >63</td>
#     </tr>
#     <tr>
#       <th id="T_6adfd_level0_row5" class="row_heading level0 row5" >radio/TV</th>
#       <td id="T_6adfd_row5_col0" class="data row5 col0" >46</td>
#       <td id="T_6adfd_row5_col1" class="data row5 col1" >86</td>
#     </tr>
#     <tr>
#       <th id="T_6adfd_level0_row6" class="row_heading level0 row6" >repairs</th>
#       <td id="T_6adfd_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_6adfd_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_6adfd_level0_row7" class="row_heading level0 row7" >vacation/others</th>
#       <td id="T_6adfd_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_6adfd_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **looking the total of values in each categorical feature**

# %%
print("Purpose : ",df_credit.Purpose.unique())
print("Sex : ",df_credit.Sex.unique())
print("Housing : ",df_credit.Housing.unique())
print("Saving accounts : ",df_credit['Saving accounts'].unique())
print("Risk : ",df_credit['Risk'].unique())
print("Checking account : ",df_credit['Checking account'].unique())
print("Aget_cat : ",df_credit['Age_cat'].unique())
# Out:
# Purpose :  ['radio/TV' 'furniture/equipment' 'car' 'business' 'domestic appliances'
#  'repairs' 'vacation/others' 'education']
# Sex :  ['female' 'male']
# Housing :  ['own' 'free' 'rent']
# Saving accounts :  ['little' 'moderate' 'quite rich' 'rich']
# Risk :  ['good' 'bad']
# Checking account :  ['moderate' 'little' 'rich']
# Aget_cat :  ['Student', 'Adult', 'Young', 'Senior']
# Categories (4, object): ['Student' < 'Young' < 'Adult' < 'Senior']

# %% [markdown]
# # 3. Perform feature engineering to prepare categorical data for machine learning models by converting them into dummy variables

# %%
def one_hot_encoder(df, nan_as_category = False):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category, drop_first=True)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# %%
#transforming the data into dummy variables
df_credit['Saving accounts'] = df_credit['Saving accounts'].fillna('no_inf')
df_credit['Checking account'] = df_credit['Checking account'].fillna('no_inf')

#Purpose to Dummies Variable
df_credit = df_credit.merge(pd.get_dummies(df_credit.Purpose, drop_first=True, prefix='Purpose'), left_index=True, right_index=True)
#Sex feature in dummies
df_credit = df_credit.merge(pd.get_dummies(df_credit.Sex, drop_first=True, prefix='Sex'), left_index=True, right_index=True)
# Housing get dummies
df_credit = df_credit.merge(pd.get_dummies(df_credit.Housing, drop_first=True, prefix='Housing'), left_index=True, right_index=True)
# Housing get Saving Accounts
df_credit = df_credit.merge(pd.get_dummies(df_credit["Saving accounts"], drop_first=True, prefix='Savings'), left_index=True, right_index=True)
# Housing get Risk
df_credit = df_credit.merge(pd.get_dummies(df_credit.Risk, prefix='Risk'), left_index=True, right_index=True)
# Housing get Checking Account
df_credit = df_credit.merge(pd.get_dummies(df_credit["Checking account"], drop_first=True, prefix='Check'), left_index=True, right_index=True)
# Housing get Age categorical
df_credit = df_credit.merge(pd.get_dummies(df_credit["Age_cat"], drop_first=True, prefix='Age_cat'), left_index=True, right_index=True)

# %%
#delete the old features
#Excluding the missing columns
del df_credit["Saving accounts"]
del df_credit["Checking account"]
del df_credit["Purpose"]
del df_credit["Sex"]
del df_credit["Housing"]
del df_credit["Age_cat"]
del df_credit["Risk"]
del df_credit['Risk_good']

# %% [markdown]
# # 4. Correlation

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df_credit.astype(float).corr(),linewidths=0.1,vmax=1.0, 
            square=True,  linecolor='white', annot=True,)
plt.show()

# %% [markdown]
# # 5. Preprocessing

# %% [markdown]
# ## Import ML library

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score # to split the data
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, fbeta_score #To evaluate our model

from sklearn.model_selection import GridSearchCV

# Algorithmns models to be compared
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from xgboost import XGBClassifier

# %%
conda install -c conda-forge xgboost
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
df_credit['Credit amount'] = np.log(df_credit['Credit amount'])

# %% [markdown]
# ## Setting X and Y variables to the prediction

# %%
#Creating the X and y variables
X = df_credit.drop('Risk_bad', axis=1).values
y = df_credit["Risk_bad"].values

# Spliting X and y into train and test version
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=42)

# %% [markdown]
# ## Splitting data

# %%
# to feed the random state
seed = 7

# prepare models
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('RF', RandomForestClassifier()))
models.append(('SVM', SVC(gamma='auto')))
models.append(('XGB', XGBClassifier()))

# evaluate each model in turn
results = []
names = []
scoring = 'recall'

for name, model in models:
        kfold = KFold(n_splits=10, shuffle=True, random_state=seed)
        cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
        results.append(cv_results)
        names.append(name)
        msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
        print(msg)
        
# boxplot algorithm comparison
fig = plt.figure(figsize=(11,6))
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# LR: 0.017143 (0.034876)
# LDA: 0.032619 (0.051684)
# KNN: 0.162284 (0.076921)
# CART: 0.343661 (0.144188)
# NB: 0.555221 (0.135100)
# RF: 0.106260 (0.077997)
# SVM: 0.063581 (0.063066)
# XGB: 0.238140 (0.123745)

# %% [markdown]
# # 6.Model 1

# %% [markdown]
# ## Use random forecaset to predict the credit score

# %%
#Seting the Hyper Parameters
param_grid = {"max_depth": [3,5, 7, 10,None],
              "n_estimators":[3,5,10,25,50,150],
              "max_features": [4,7,15,20]}

#Creating the classifier
model = RandomForestClassifier(random_state=2)

grid_search = GridSearchCV(model, param_grid=param_grid, cv=5, scoring='recall', verbose=4)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV 1/5] END max_depth=3, max_features=4, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=4, n_estimators=3;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=4, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=4, n_estimators=3;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=4, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=4, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=4, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=4, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=4, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=4, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=7, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=7, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=7, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=7, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=7, n_estimators=3;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=7, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=7, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=7, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=7, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=7, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=7, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=7, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=7, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=7, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=7, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=7, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=7, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=7, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=7, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=7, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=7, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=7, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=7, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=7, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=7, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=15, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=15, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=15, n_estimators=3;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=15, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=15, n_estimators=3;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=15, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=15, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=15, n_estimators=5;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=15, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=15, n_estimators=5;, score=0.087 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=15, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=15, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=15, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=15, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=15, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=15, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=15, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=15, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=15, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=15, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=15, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=15, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=15, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=15, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=15, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=15, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=15, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=15, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=15, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=15, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 1/5] END max_depth=3, max_features=20, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=20, n_estimators=3;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=20, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=20, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=20, n_estimators=3;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=20, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=20, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=20, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=20, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=20, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=20, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=20, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=20, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=20, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=20, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=20, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=20, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=20, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=20, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=20, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=20, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=3, max_features=20, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=3, max_features=20, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=3, max_features=20, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=3, max_features=20, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=3, max_features=20, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/5] END max_depth=3, max_features=20, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 3/5] END max_depth=3, max_features=20, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 4/5] END max_depth=3, max_features=20, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 5/5] END max_depth=3, max_features=20, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 1/5] END max_depth=5, max_features=4, n_estimators=3;, score=0.083 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=4, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=4, n_estimators=3;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=4, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=4, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=4, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=4, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=4, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=4, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=4, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=4, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/5] END max_depth=5, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 3/5] END max_depth=5, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 4/5] END max_depth=5, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 5/5] END max_depth=5, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 1/5] END max_depth=5, max_features=7, n_estimators=3;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=7, n_estimators=3;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=7, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=7, n_estimators=3;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=7, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=7, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=7, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=7, n_estimators=5;, score=0.217 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=7, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=7, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=7, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=7, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=7, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=7, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=7, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=7, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=7, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=7, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=7, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=7, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=7, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/5] END max_depth=5, max_features=7, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 3/5] END max_depth=5, max_features=7, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 4/5] END max_depth=5, max_features=7, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 5/5] END max_depth=5, max_features=7, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 1/5] END max_depth=5, max_features=15, n_estimators=3;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=15, n_estimators=3;, score=0.304 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=15, n_estimators=3;, score=0.304 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=15, n_estimators=3;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=15, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=15, n_estimators=5;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=15, n_estimators=5;, score=0.261 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=15, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=15, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=15, n_estimators=5;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=15, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=15, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=15, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=15, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=15, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=15, n_estimators=25;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=15, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=15, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=15, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=15, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=15, n_estimators=50;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=15, n_estimators=50;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=15, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=15, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=15, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=15, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/5] END max_depth=5, max_features=15, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 3/5] END max_depth=5, max_features=15, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 4/5] END max_depth=5, max_features=15, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 5/5] END max_depth=5, max_features=15, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 1/5] END max_depth=5, max_features=20, n_estimators=3;, score=0.083 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=20, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=20, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=20, n_estimators=3;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=20, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=20, n_estimators=5;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=20, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=20, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=20, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=20, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=20, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=20, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=20, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=20, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=20, n_estimators=10;, score=0.174 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=20, n_estimators=25;, score=0.083 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=20, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=20, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=20, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=5, max_features=20, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=5, max_features=20, n_estimators=50;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=5, max_features=20, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=5, max_features=20, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=5, max_features=20, n_estimators=50;, score=0.000 total time=   0.1s
# [CV 5/5] END max_depth=5, max_features=20, n_estimators=50;, score=0.043 total time=   0.1s
# [CV 1/5] END max_depth=5, max_features=20, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 2/5] END max_depth=5, max_features=20, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 3/5] END max_depth=5, max_features=20, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=20, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 5/5] END max_depth=5, max_features=20, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 1/5] END max_depth=7, max_features=4, n_estimators=3;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=4, n_estimators=3;, score=0.348 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=4, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=4, n_estimators=3;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=4, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=4, n_estimators=5;, score=0.083 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=4, n_estimators=5;, score=0.261 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=4, n_estimators=5;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=4, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=4, n_estimators=5;, score=0.087 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=4, n_estimators=10;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=4, n_estimators=10;, score=0.174 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=4, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=4, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=4, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 2/5] END max_depth=7, max_features=4, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 3/5] END max_depth=7, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 4/5] END max_depth=7, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 5/5] END max_depth=7, max_features=4, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 1/5] END max_depth=7, max_features=7, n_estimators=3;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=7, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=7, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=7, n_estimators=3;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=7, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=7, n_estimators=5;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=7, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=7, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=7, n_estimators=5;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=7, n_estimators=5;, score=0.261 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=7, n_estimators=10;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=7, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=7, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=7, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=7, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=7, n_estimators=25;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=7, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=7, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=7, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=7, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=7, n_estimators=50;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=7, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=7, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=7, n_estimators=150;, score=0.042 total time=   0.1s
# [CV 2/5] END max_depth=7, max_features=7, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 3/5] END max_depth=7, max_features=7, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 4/5] END max_depth=7, max_features=7, n_estimators=150;, score=0.000 total time=   0.1s
# [CV 5/5] END max_depth=7, max_features=7, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 1/5] END max_depth=7, max_features=15, n_estimators=3;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=15, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=15, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=15, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=15, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=15, n_estimators=5;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=15, n_estimators=5;, score=0.217 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=15, n_estimators=5;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=15, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=15, n_estimators=5;, score=0.217 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=15, n_estimators=10;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=15, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=15, n_estimators=10;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=15, n_estimators=10;, score=0.174 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=15, n_estimators=10;, score=0.174 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=15, n_estimators=25;, score=0.083 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=15, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=15, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=15, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=15, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=15, n_estimators=50;, score=0.125 total time=   0.1s
# [CV 2/5] END max_depth=7, max_features=15, n_estimators=50;, score=0.087 total time=   0.1s
# [CV 3/5] END max_depth=7, max_features=15, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=15, n_estimators=50;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=15, n_estimators=50;, score=0.130 total time=   0.1s
# [CV 1/5] END max_depth=7, max_features=15, n_estimators=150;, score=0.083 total time=   0.1s
# [CV 2/5] END max_depth=7, max_features=15, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=15, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=15, n_estimators=150;, score=0.087 total time=   0.1s
# [CV 5/5] END max_depth=7, max_features=15, n_estimators=150;, score=0.087 total time=   0.1s
# [CV 1/5] END max_depth=7, max_features=20, n_estimators=3;, score=0.167 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=20, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=20, n_estimators=3;, score=0.304 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=20, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=20, n_estimators=3;, score=0.087 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=20, n_estimators=5;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=20, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=20, n_estimators=5;, score=0.130 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=20, n_estimators=5;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=20, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=20, n_estimators=10;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=20, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=20, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=20, n_estimators=10;, score=0.174 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=20, n_estimators=10;, score=0.217 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=20, n_estimators=25;, score=0.083 total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=20, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=20, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=20, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=20, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=20, n_estimators=50;, score=0.083 total time=   0.1s
# [CV 2/5] END max_depth=7, max_features=20, n_estimators=50;, score=0.043 total time=   0.1s
# [CV 3/5] END max_depth=7, max_features=20, n_estimators=50;, score=0.000 total time=   0.1s
# [CV 4/5] END max_depth=7, max_features=20, n_estimators=50;, score=0.174 total time=   0.1s
# [CV 5/5] END max_depth=7, max_features=20, n_estimators=50;, score=0.087 total time=   0.1s
# [CV 1/5] END max_depth=7, max_features=20, n_estimators=150;, score=0.083 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=20, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=20, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=20, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 5/5] END max_depth=7, max_features=20, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 1/5] END max_depth=10, max_features=4, n_estimators=3;, score=0.208 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=4, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=4, n_estimators=3;, score=0.261 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=4, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=4, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=4, n_estimators=5;, score=0.167 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=4, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=4, n_estimators=5;, score=0.217 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=4, n_estimators=5;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=4, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=4, n_estimators=10;, score=0.083 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=4, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=4, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=4, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=4, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=4, n_estimators=25;, score=0.042 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=4, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=4, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=4, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=4, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=4, n_estimators=50;, score=0.000 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=4, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=4, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=4, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=4, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=4, n_estimators=150;, score=0.042 total time=   0.1s
# [CV 2/5] END max_depth=10, max_features=4, n_estimators=150;, score=0.000 total time=   0.2s
# [CV 3/5] END max_depth=10, max_features=4, n_estimators=150;, score=0.087 total time=   0.1s
# [CV 4/5] END max_depth=10, max_features=4, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 5/5] END max_depth=10, max_features=4, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 1/5] END max_depth=10, max_features=7, n_estimators=3;, score=0.333 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=7, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=7, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=7, n_estimators=3;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=7, n_estimators=3;, score=0.304 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=7, n_estimators=5;, score=0.250 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=7, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=7, n_estimators=5;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=7, n_estimators=5;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=7, n_estimators=5;, score=0.348 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=7, n_estimators=10;, score=0.167 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=7, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=7, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=7, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=7, n_estimators=10;, score=0.217 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=7, n_estimators=25;, score=0.083 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=7, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=7, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=7, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=7, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=7, n_estimators=50;, score=0.083 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=7, n_estimators=50;, score=0.174 total time=   0.1s
# [CV 3/5] END max_depth=10, max_features=7, n_estimators=50;, score=0.087 total time=   0.1s
# [CV 4/5] END max_depth=10, max_features=7, n_estimators=50;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=7, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=7, n_estimators=150;, score=0.125 total time=   0.2s
# [CV 2/5] END max_depth=10, max_features=7, n_estimators=150;, score=0.087 total time=   0.1s
# [CV 3/5] END max_depth=10, max_features=7, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 4/5] END max_depth=10, max_features=7, n_estimators=150;, score=0.043 total time=   0.1s
# [CV 5/5] END max_depth=10, max_features=7, n_estimators=150;, score=0.130 total time=   0.1s
# [CV 1/5] END max_depth=10, max_features=15, n_estimators=3;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=15, n_estimators=3;, score=0.261 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=15, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=15, n_estimators=3;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=15, n_estimators=3;, score=0.348 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=15, n_estimators=5;, score=0.167 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=15, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=15, n_estimators=5;, score=0.130 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=15, n_estimators=5;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=15, n_estimators=5;, score=0.261 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=15, n_estimators=10;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=15, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=15, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=15, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=15, n_estimators=10;, score=0.217 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=15, n_estimators=25;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=15, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=15, n_estimators=25;, score=0.000 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=15, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=15, n_estimators=25;, score=0.174 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=15, n_estimators=50;, score=0.083 total time=   0.1s
# [CV 2/5] END max_depth=10, max_features=15, n_estimators=50;, score=0.043 total time=   0.1s
# [CV 3/5] END max_depth=10, max_features=15, n_estimators=50;, score=0.043 total time=   0.1s
# [CV 4/5] END max_depth=10, max_features=15, n_estimators=50;, score=0.130 total time=   0.1s
# [CV 5/5] END max_depth=10, max_features=15, n_estimators=50;, score=0.130 total time=   0.1s
# [CV 1/5] END max_depth=10, max_features=15, n_estimators=150;, score=0.125 total time=   0.2s
# [CV 2/5] END max_depth=10, max_features=15, n_estimators=150;, score=0.130 total time=   0.2s
# [CV 3/5] END max_depth=10, max_features=15, n_estimators=150;, score=0.130 total time=   0.2s
# [CV 4/5] END max_depth=10, max_features=15, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 5/5] END max_depth=10, max_features=15, n_estimators=150;, score=0.174 total time=   0.2s
# [CV 1/5] END max_depth=10, max_features=20, n_estimators=3;, score=0.208 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=20, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=20, n_estimators=3;, score=0.304 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=20, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=20, n_estimators=3;, score=0.348 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=20, n_estimators=5;, score=0.208 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=20, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=20, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=20, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=20, n_estimators=5;, score=0.304 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=20, n_estimators=10;, score=0.167 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=20, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=20, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=20, n_estimators=10;, score=0.174 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=20, n_estimators=10;, score=0.304 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=20, n_estimators=25;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=20, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=20, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=20, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=20, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=20, n_estimators=50;, score=0.167 total time=   0.1s
# [CV 2/5] END max_depth=10, max_features=20, n_estimators=50;, score=0.130 total time=   0.1s
# [CV 3/5] END max_depth=10, max_features=20, n_estimators=50;, score=0.130 total time=   0.1s
# [CV 4/5] END max_depth=10, max_features=20, n_estimators=50;, score=0.087 total time=   0.1s
# [CV 5/5] END max_depth=10, max_features=20, n_estimators=50;, score=0.174 total time=   0.1s
# [CV 1/5] END max_depth=10, max_features=20, n_estimators=150;, score=0.125 total time=   0.2s
# [CV 2/5] END max_depth=10, max_features=20, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 3/5] END max_depth=10, max_features=20, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 4/5] END max_depth=10, max_features=20, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 5/5] END max_depth=10, max_features=20, n_estimators=150;, score=0.217 total time=   0.2s
# [CV 1/5] END max_depth=None, max_features=4, n_estimators=3;, score=0.417 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=4, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=4, n_estimators=3;, score=0.304 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=4, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=4, n_estimators=3;, score=0.261 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=4, n_estimators=5;, score=0.500 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=4, n_estimators=5;, score=0.261 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=4, n_estimators=5;, score=0.217 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=4, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=4, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=4, n_estimators=10;, score=0.208 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=4, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=4, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=4, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=4, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=4, n_estimators=25;, score=0.208 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=4, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=4, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=4, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=4, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=4, n_estimators=50;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=4, n_estimators=50;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=4, n_estimators=50;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=4, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=4, n_estimators=50;, score=0.087 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=4, n_estimators=150;, score=0.208 total time=   0.1s
# [CV 2/5] END max_depth=None, max_features=4, n_estimators=150;, score=0.130 total time=   0.1s
# [CV 3/5] END max_depth=None, max_features=4, n_estimators=150;, score=0.087 total time=   0.1s
# [CV 4/5] END max_depth=None, max_features=4, n_estimators=150;, score=0.043 total time=   0.2s
# [CV 5/5] END max_depth=None, max_features=4, n_estimators=150;, score=0.130 total time=   0.1s
# [CV 1/5] END max_depth=None, max_features=7, n_estimators=3;, score=0.375 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=7, n_estimators=3;, score=0.304 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=7, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=7, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=7, n_estimators=3;, score=0.304 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=7, n_estimators=5;, score=0.292 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=7, n_estimators=5;, score=0.261 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=7, n_estimators=5;, score=0.174 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=7, n_estimators=5;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=7, n_estimators=5;, score=0.304 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=7, n_estimators=10;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=7, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=7, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=7, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=7, n_estimators=10;, score=0.174 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=7, n_estimators=25;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=7, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=7, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=7, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=7, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=7, n_estimators=50;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=7, n_estimators=50;, score=0.043 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=7, n_estimators=50;, score=0.130 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=7, n_estimators=50;, score=0.087 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=7, n_estimators=50;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=7, n_estimators=150;, score=0.083 total time=   0.1s
# [CV 2/5] END max_depth=None, max_features=7, n_estimators=150;, score=0.130 total time=   0.1s
# [CV 3/5] END max_depth=None, max_features=7, n_estimators=150;, score=0.130 total time=   0.1s
# [CV 4/5] END max_depth=None, max_features=7, n_estimators=150;, score=0.087 total time=   0.1s
# [CV 5/5] END max_depth=None, max_features=7, n_estimators=150;, score=0.174 total time=   0.1s
# [CV 1/5] END max_depth=None, max_features=15, n_estimators=3;, score=0.292 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=15, n_estimators=3;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=15, n_estimators=3;, score=0.261 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=15, n_estimators=3;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=15, n_estimators=3;, score=0.261 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=15, n_estimators=5;, score=0.292 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=15, n_estimators=5;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=15, n_estimators=5;, score=0.261 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=15, n_estimators=5;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=15, n_estimators=5;, score=0.304 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=15, n_estimators=10;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=15, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=15, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=15, n_estimators=10;, score=0.174 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=15, n_estimators=10;, score=0.217 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=15, n_estimators=25;, score=0.125 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=15, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=15, n_estimators=25;, score=0.087 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=15, n_estimators=25;, score=0.043 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=15, n_estimators=25;, score=0.304 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=15, n_estimators=50;, score=0.167 total time=   0.1s
# [CV 2/5] END max_depth=None, max_features=15, n_estimators=50;, score=0.043 total time=   0.1s
# [CV 3/5] END max_depth=None, max_features=15, n_estimators=50;, score=0.000 total time=   0.1s
# [CV 4/5] END max_depth=None, max_features=15, n_estimators=50;, score=0.087 total time=   0.1s
# [CV 5/5] END max_depth=None, max_features=15, n_estimators=50;, score=0.261 total time=   0.1s
# [CV 1/5] END max_depth=None, max_features=15, n_estimators=150;, score=0.167 total time=   0.2s
# [CV 2/5] END max_depth=None, max_features=15, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 3/5] END max_depth=None, max_features=15, n_estimators=150;, score=0.043 total time=   0.2s
# [CV 4/5] END max_depth=None, max_features=15, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 5/5] END max_depth=None, max_features=15, n_estimators=150;, score=0.174 total time=   0.2s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=3;, score=0.250 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=3;, score=0.174 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=3;, score=0.348 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=3;, score=0.217 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=5;, score=0.250 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=5;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=5;, score=0.130 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=5;, score=0.261 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=5;, score=0.261 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=10;, score=0.083 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=10;, score=0.087 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=10;, score=0.043 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=10;, score=0.130 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=25;, score=0.167 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=25;, score=0.130 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=25;, score=0.304 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=50;, score=0.167 total time=   0.1s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=50;, score=0.087 total time=   0.1s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=50;, score=0.130 total time=   0.1s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=50;, score=0.130 total time=   0.1s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=50;, score=0.261 total time=   0.1s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=150;, score=0.167 total time=   0.2s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=150;, score=0.130 total time=   0.2s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=150;, score=0.087 total time=   0.2s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=150;, score=0.217 total time=   0.2s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=2),
#              param_grid={'max_depth': [3, 5, 7, 10, None],
#                          'max_features': [4, 7, 15, 20],
#                          'n_estimators': [3, 5, 10, 25, 50, 150]},
#              scoring='recall', verbose=4)

# %%
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.27463768115942033
# {'max_depth': None, 'max_features': 4, 'n_estimators': 3}

# %%
rf = RandomForestClassifier(max_depth=None, max_features=10, n_estimators=15, random_state=2)

#trainning with the best params
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features=10, n_estimators=15, random_state=2)

# %%
#Testing the model 
#Predicting using our  model
y_pred = rf.predict(X_test)

# Verificaar os resultados obtidos
print(accuracy_score(y_test,y_pred))
print("\n")
print(confusion_matrix(y_test, y_pred))
print("\n")
print(fbeta_score(y_test, y_pred, beta=2))
# Out:
# 0.6259541984732825
#
#
# [[78  9]
#  [40  4]]
#
#
# 0.10582010582010583

# %% [markdown]
# # 7. Model 2

# %%
from sklearn.utils import resample
from sklearn.metrics import roc_curve

# %%
# Criando o classificador logreg
GNB = GaussianNB()

# Fitting with train data
model = GNB.fit(X_train, y_train)

# %%
# Printing the Training Score
print("Training score data: ")
print(model.score(X_train, y_train))
# Out:
# Training score data:
# 0.5242966751918159

# %%
y_pred = model.predict(X_test)

print(accuracy_score(y_test,y_pred))
print("\n")
print(confusion_matrix(y_test, y_pred))
print("\n")
print(classification_report(y_test, y_pred))
# Out:
# 0.4580152671755725
#
#
# [[38 49]
#  [22 22]]
#
#
#               precision    recall  f1-score   support
#
#        False       0.63      0.44      0.52        87
#         True       0.31      0.50      0.38        44
#
#     accuracy                           0.46       131
#    macro avg       0.47      0.47      0.45       131
# weighted avg       0.52      0.46      0.47       131

# %% [markdown]
# ## Vertify the ROC curve

# %%
#Predicting proba
y_pred_prob = model.predict_proba(X_test)[:,1]

# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Plot ROC curve
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest

# %%
features = []
features.append(('pca', PCA(n_components=2)))
features.append(('select_best', SelectKBest(k=6)))
feature_union = FeatureUnion(features)
# create pipeline
estimators = []
estimators.append(('feature_union', feature_union))
estimators.append(('logistic', GaussianNB()))
model = Pipeline(estimators)
# evaluate pipeline
seed = 7
kfold = KFold(n_splits=10, shuffle=True,random_state=seed)
results = cross_val_score(model, X_train, y_train, cv=kfold)
print(results.mean())
# Out:
# 0.5193589743589744

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(accuracy_score(y_test,y_pred))
print("\n")
print(confusion_matrix(y_test, y_pred))
print("\n")
print(fbeta_score(y_test, y_pred, beta=2))
# Out:
# 0.5648854961832062
#
#
# [[55 32]
#  [25 19]]
#
#
# 0.41850220264317184

# %% [markdown]
# # 8. Implementing a pipeline of models

# %%
#Seting the Hyper Parameters
param_test1 = {
 'max_depth':[3,5,6,10],
 'min_child_weight':[3,5,10],
 'gamma':[0.0, 0.1, 0.2, 0.3, 0.4],
# 'reg_alpha':[1e-5, 1e-2, 0.1, 1, 10],
 'subsample':[i/100.0 for i in range(75,90,5)],
 'colsample_bytree':[i/100.0 for i in range(75,90,5)]
}

#Creating the classifier
model_xg = XGBClassifier(random_state=2)

grid_search = GridSearchCV(model_xg, param_grid=param_test1, cv=5, scoring='recall')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=2, ...),
#              param_grid={'colsample_bytree': [0.75, 0.8, 0.85],
#                          'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                          'max_depth': [3, 5, 6, 10],
#                          'min_child_weight': [3, 5, 10],
#                          'subsample': [0.75, 0.8, 0.85]},
#              scoring='recall')

# %%
grid_search.best_score_
grid_search.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'gamma': 0.3,
#  'max_depth': 6,
#  'min_child_weight': 3,
#  'subsample': 0.8}

# %%
y_pred = grid_search.predict(X_test)

# Verificaar os resultados obtidos
print(accuracy_score(y_test,y_pred))
print("\n")
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.648854961832061
#
#
# [[76 11]
#  [35  9]]
